# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WayHome_logs_C.csv', delimiter=',')
df = df[df['id'] == 55]
plt.plot(df['position_x'], df['position_y'])
plt.xlim(0, 8)
# Out:
# (0.0, 8.0)
